# %% [markdown]
# It is critical for a model to recognize that it is presented with an unreasonable input (e.g., OOD); in the real world this could be used for an autonomous vehicle yielding control to a human if the perception system detects that it is presented with such an input image as it is expected that model’s performance on this datapoint will be poor.  If we're sucessful in detecting such a distribution shift, model can pass this information downstream to avoid potentially disastrous prediction before it actually happens.
#
# In this tutorial we will leverage the “uncertainty estimation” functionality provided by capsa for anomaly detection.

# %%
# !pip install capsa
# !wget https://github.com/themis-ai/capsa/raw/main/notebooks/utils_depth/utils.py
# !wget https://github.com/themis-ai/capsa/raw/main/notebooks/utils_depth/models.py
# !wget https://github.com/themis-ai/capsa/raw/main/notebooks/utils_depth/config.py
# !wget https://github.com/themis-ai/capsa/raw/main/notebooks/utils_depth/adversarial.py

# %%
# !wget http://argo-1.themisai.io/demos/nyu_depth/nyu.h5
# # download and extract ood dataset
# !wget http://6.869.csail.mit.edu/fa17/miniplaces/data.tar.gz
# !mkdir miniplaces & tar -xzf data.tar.gz -C miniplaces

# %%
import tensorflow as tf
import utils_depth.config as config
from utils_depth.utils import notebook_select_gpu
notebook_select_gpu(1)

# %%
from utils_depth.utils import get_datasets
ds_train, ds_test, ds_ood = get_datasets(
    id_path = "nyu.h5",
    ood_path = "miniplaces",
)

# %% [markdown]
# ## Train model
#
# We'll use the same "base model" as in the previous tutorial (part 1). Let's also use  [EnsembleWrapper](https://themisai.io/capsa/api_documentation/EnsembleWrapper.html) to estimate epistemic uncertainty of the model. Same as with any other Capsa wrapper, user could simply wrap their model with it. This method of estimating the model uncertainty is accurate, although it's very computationally expensive. Luckily, capsa implements multiple different epistemic wrappers.
#
# ⭐ Please feel free to experiment and in the cell below instead of the EnsembleWrapper use one of the following ``Capsa`` epistemic wrappers: [DropoutWrapper](https://themisai.io/capsa/api_documentation/DropoutWrapper.html), [VAEWrapper](https://themisai.io/capsa/api_documentation/VAEWrapper.html).

# %%
from utils_depth.models import unet
from capsa import EnsembleWrapper

base_model = unet()

model = EnsembleWrapper(base_model, num_members=3)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=config.LR),
    loss="mse",
)

# %%
history = model.fit(
    ds_train,
    epochs=config.EP,
    validation_data=ds_test,
)
# Out:
# Epoch 1/20
# 256/256 [==============================] - 58s 199ms/step - usermodel_0_compiled_loss: 0.0943 - usermodel_1_compiled_loss: 0.1157 - usermodel_2_compiled_loss: 0.0989 - average_loss: 0.1030 - val_usermodel_0_compiled_loss: 0.0583 - val_usermodel_1_compiled_loss: 0.0634 - val_usermodel_2_compiled_loss: 0.0585
# Epoch 2/20
# 256/256 [==============================] - 52s 202ms/step - usermodel_0_compiled_loss: 0.0519 - usermodel_1_compiled_loss: 0.0549 - usermodel_2_compiled_loss: 0.0509 - average_loss: 0.0526 - val_usermodel_0_compiled_loss: 0.0462 - val_usermodel_1_compiled_loss: 0.0475 - val_usermodel_2_compiled_loss: 0.0439
# Epoch 3/20
20
# 256/256 [==============================] - 52s 204ms/step - usermodel_0_compiled_loss: 0.0117 - usermodel_1_compiled_loss: 0.0116 - usermodel_2_compiled_loss: 0.0105 - average_loss: 0.0112 - val_usermodel_0_compiled_loss: 0.0113 - val_usermodel_1_compiled_loss: 0.0112 - val_usermodel_2_compiled_loss: 0.0101
# Epoch 14/20
# 256/256 [==============================] - 52s 204ms/step - usermodel_0_compiled_loss: 0.0109 - usermodel_1_compiled_loss: 0.0108 - usermodel_2_compiled_loss: 0.0098 - average_loss: 0.0105 - val_usermodel_0_compiled_loss: 0.0106 - val_usermodel_1_compiled_loss: 0.0105 - val_usermodel_2_compiled_loss: 0.0095
# Epoch 15/20
# 256/256 [==============================] - 52s 204ms/step - usermodel_0_compiled_loss: 0.0103 - usermodel_1_compiled_loss: 0.0102 - usermodel_2_compiled_loss: 0.0092 - average_loss: 0.0099 - val_usermodel_0_compiled_loss: 0.0100 - val_usermodel_1_compiled_loss: 0.0099 - val_usermodel_2_compiled_loss: 0.0090
# Epoch 16/20
# 256/256 [==============================] - 52s 204ms/step - usermodel_0_compiled_loss: 0.0097 - usermodel_1_compiled_loss: 0.0096 - usermodel_2_compiled_loss: 0.0087 - average_loss: 0.0094 - val_usermodel_0_compiled_loss: 0.0095 - val_usermodel_1_compiled_loss: 0.0094 - val_usermodel_2_compiled_loss: 0.0085
# Epoch 17/20
# 256/256 [==============================] - 52s 204ms/step - usermodel_0_compiled_loss: 0.0092 - usermodel_1_compiled_loss: 0.0091 - usermodel_2_compiled_loss: 0.0083 - average_loss: 0.0089 - val_usermodel_0_compiled_loss: 0.0090 - val_usermodel_1_compiled_loss: 0.0089 - val_usermodel_2_compiled_loss: 0.0081
# Epoch 18/20
# 256/256 [==============================] - 52s 204ms/step - usermodel_0_compiled_loss: 0.0088 - usermodel_1_compiled_loss: 0.0087 - usermodel_2_compiled_loss: 0.0079 - average_loss: 0.0084 - val_usermodel_0_compiled_loss: 0.0086 - val_usermodel_1_compiled_loss: 0.0085 - val_usermodel_2_compiled_loss: 0.0077
# Epoch 19/20
# 256/256 [==============================] - 52s 204ms/step - usermodel_0_compiled_loss: 0.0084 - usermodel_1_compiled_loss: 0.0083 - usermodel_2_compiled_loss: 0.0075 - average_loss: 0.0081 - val_usermodel_0_compiled_loss: 0.0082 - val_usermodel_1_compiled_loss: 0.0081 - val_usermodel_2_compiled_loss: 0.0074
# Epoch 20/20
# 256/256 [==============================] - 52s 204ms/step - usermodel_0_compiled_loss: 0.0080 - usermodel_1_compiled_loss: 0.0079 - usermodel_2_compiled_loss: 0.0072 - average_loss: 0.0077 - val_usermodel_0_compiled_loss: 0.0078 - val_usermodel_1_compiled_loss: 0.0078 - val_usermodel_2_compiled_loss: 0.0071

# %% [markdown]
# Perfect! We've traind our risk-aware model, now let's look at the loss curves.

# %%
from utils_depth.utils import plot_loss
plot_loss(history)

# %% [markdown]
# The loss curves look good.
#
# As you may notice in addition to the loss metrics specified in compalation step ``Capsa`` also logs some additional losses these are computed under the hood to enable this risk aware functionality mentioned earlier.

# %% [markdown]
# Let's look at the calibration plot that the model produces to quantitatively assess the quality of the risk estimate.

# %%
from utils_depth.utils import gen_calibration_plot
gen_calibration_plot(model, ds_test)

# %% [markdown]
# ##  Anomaly detection

# %% [markdown]
# The core idea behind the approach is that a model’s epistemic uncertainty on out-of-distribution (OOD) data is naturally higher than the same model’s epistemic uncertainty on indistribution (ID) data. Thus, given a risk aware model we can visualize density histograms of per image uncertainty estimates provided by a model on both ID (unseen test-set for NYU Depth V2 dataset) and OOD data (ApolloScapes).
#
# In other words, we would expect that the epistemic uncertainty estimate will help us to separate the out-of-distribution data.
#
# Let's plot the histogram and see...

# %%
from utils_depth.utils import gen_ood_comparison
iid_risk, ood_risk = gen_ood_comparison(ds_test, ds_ood, model, reduce='per_img', is_show=True, is_return=True)

# %% [markdown]
# 🤩 Amazing! Indeed, we see that the out-of-distribution datapoints have higher model uncertainty and we see two clearly pronounced peaks corresponding to the different datasets.
#
# At this point, OOD (anomaly) detection is possible by a simple thresholding. We can use AUC-ROC to quantitatively assess the separation of the two density histograms, a higher AUC indicates a better quality of the separation.

# %%
from utils_depth.utils import plot_roc
plot_roc(iid_risk, ood_risk, model.metric_name)

# %% [markdown]
# ## Adversarial perturbations

# %% [markdown]
# Further, the approach described above could be used to detect adversarial attacks (perturbations). A way of interpreting the adversarial perturbations is as a way of gradually turning ID data points into OOD. Such a granular control allows for a better model introspection.
#
# After we've trained the model, we compute gradients with respect to the input image and apply it with varying epsilon.
# In other words, the approach is:
#
# ```
# for each test image, compute gx = dL/dx (the gradient of the loss with respect to the input image pixels)
# for different levels of adversarial noise k = [0, ..., 0.1]:
#  perturb the test images:  x_new = x_old + k * tf.sign(gx)
#  run the model on these images and compute predictions and risk estimate
# ```

# %% [markdown]
# The cell below simply implements the pseudocode above and caches the predictions.

# %%
from utils_depth.adversarial import get_adversarial_predictions
df_risk, risk_id, list_risk_ood, list_vis = get_adversarial_predictions(model, ds_test)

# %% [markdown]
# Simularly as we did earlier, let's visualize density histograms of per image uncertainty estimates provided by a model on both the test data (in distribution) and the preturbed data (out of distribution).
#
# We see that as the epsilon of the perturbation increases the density histograms of per image uncertainty estimates provided by a model on both the ID and perturbed images become more disentangled and thus the quality of separation increases.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(8, 5))
plot = sns.histplot(data=df_risk, kde=True, bins=50, alpha=0.6, linewidth=0, palette="mako")
plot.set(xlabel="Epistemic risk", ylabel="PDF")
plt.show()

# %% [markdown]
# Simularly as we did earlier let's use AUC-ROC to quantitatively assess the separation of the two density histograms, a higher AUC indicates a better quality of the separation.

# %%
model_name = model.metric_name
plot_roc(risk_id, list_risk_ood, model_name, is_palette=True)

# %% [markdown]
# Finally, let's visualize the images perturbed with varying degrees. We plot the input to the model on the first row; model's predictions on the second row; and the risk estimate (outputed by the model) on the third row.
#
# We see that even though some of the perturbed images are not immediately distinguishable to a human eye, the method described above successfully detects the altered input images. We also see that as the more the image becomes an out of distribution, the more the depth estimate degrades.
#
# Luckily, since our model is risk aware we're able to capture the model's uncertainty in its predictions.

# %%
from utils_depth.adversarial import visualize_adversarial
visualize_adversarial(list_vis)
